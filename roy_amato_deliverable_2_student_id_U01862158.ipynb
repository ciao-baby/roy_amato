# %% [markdown]
# <a href="https://colab.research.google.com/github/ciao-baby/roy_amato/blob/main/roy_amato_deliverable_2_student_id_U01862158.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/2020-2025.csv")

df.head(196)
# Out:
#          Country    2020      2021      2022      2023      2024      2025
# 0    Afghanistan   20136   14278.0   14501.0   17248.0       NaN       NaN
# 1        Albania   15271   18086.0   19185.0   23388.0   27259.0   28372.0
# 2        Algeria  164774  185850.0  225709.0  247789.0  264913.0  268885.0
# 3        Andorra    2885    3325.0    3376.0    3786.0    4038.0    4035.0
# 4         Angola   66521   84375.0  142442.0  109764.0  115946.0  113343.0
# ..           ...     ...       ...       ...       ...       ...       ...
# 191      Vietnam  346310  370076.0  411068.0  433008.0  459472.0  490970.0
# 192    Palestine   15532   18109.0   19166.0   17848.0       NaN       NaN
# 193        Yemen   20220   19394.0   23534.0   19412.0   19101.0   17401.0
# 194       Zambia   18138   22096.0   29164.0   27578.0   26326.0   28910.0
# 195     Zimbabwe   26878   36016.0   32613.0   35144.0   35224.0   38172.0
#
# [196 rows x 7 columns]

# %%
import pandas as pd

df = pd.read_csv("/content/2020-2025.csv")

# Example: get top 10 highest values from a column
top10 = df.nlargest(10, "2020")

print(top10)
# Out:
#             Country      2020        2021        2022        2023        2024  \
# 186   United States  21354125  23681175.0  26006900.0  27720725.0  29184900.0
# 36            China  15103357  18190803.0  18307816.0  18270351.0  18748009.0
# 85            Japan   5054069   5039148.0   4262146.0   4213167.0   4026211.0
# 64          Germany   3936989   4351188.0   4166872.0   4527009.0   4658526.0
# 185  United Kingdom   2698705   3144079.0   3125404.0   3371118.0   3644636.0
# 77            India   2674852   3167271.0   3346107.0   3638490.0   3909097.0
# 60           France   2645806   2968405.0   2797049.0   3056880.0   3162023.0
# 83            Italy   1905956   2180656.0   2105722.0   2305271.0   2372059.0
# 90      South Korea   1744456   1942314.0   1799363.0   1839058.0   1869714.0
# 32           Canada   1655685   2022382.0   2190411.0   2173340.0   2241253.0
#
#            2025
# 186  30507217.0
# 36   19231705.0
# 85    4186431.0
# 64    4744804.0
# 185   3839180.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv(
    "/content/2020-2025.csv",
    usecols=["Country", "2020"]
)

# Get top 10 by highest 2020 values
top10 = df.sort_values(by="2020", ascending=False).head(10)

# Plot bar chart
top10.plot(kind="bar", x="Country", y="2020", figsize=(10,6), legend=False)
plt.ylabel("2020 Value")
plt.title("Top 10 Countries by 2020 Value")
plt.xticks(rotation=45)
plt.show()
